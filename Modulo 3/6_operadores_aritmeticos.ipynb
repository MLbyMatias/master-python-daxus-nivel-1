# %% [markdown]
# # Operadores aritméticos
#
# Todos hemos utilizado operadores aritméticos en escuela/colegio. Durante los primeros años de estudio aprendemos a sumar, restar, multiplicar y dividir.
#
# En `Python` también tenemos estos operadores para realizar estos cálculos!

# %% [markdown]
# # 1. Suma

# %%
print(9 + 3)
# Out:
# 12

# %% [markdown]
# # 2. Resta

# %%
print(24-4)
# Out:
# 20

# %%
print(-4-24)
# Out:
# -28

# %% [markdown]
# # 3. Multiplicación

# %%
print(-8 * -5)
# Out:
# 40

# %% [markdown]
# # 4. División

# %%
print(100/10)
# Out:
# 10

# %% [markdown]
# # 4.1 División entera

# %%
print(100//3)
# Out:
# 33

# %% [markdown]
# # 4.2 Módulo

# %%
print(5%3)
# Out:
# 2

# %% [markdown]
# # Exponenciación

# %%
print(2**3)
# Out:
# 8

# %% [markdown]
# ## Presedencia
#
# 1. Paréntesis.
#
# 2. Exponentes.
#
# 3. Multiplicaciones y divisiones (izquierda a derecha).
#
# 4. Sumas y restas.

# %%
print(12*3 + 12/(3 - 6 + 8))
# Out:
# 38.4
