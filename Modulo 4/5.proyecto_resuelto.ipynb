# %% [markdown]
# # 🛒 Sistema de control de inventario
#
# ### 🏗️ Funcionalidades
#
# ✅ Normalización del nombre del producto (`title()`, `strip()`)
#
# ✅ Mostrar los datos formateados en pantalla con `f-strings`
#
# ✅ Separación visual con caracteres(`"-" * 30`) para un diseño más organizado

# %%
print("🛒 Bienvenidos")

# Solicitando información al usuario
producto = input("Ingrese el nombre del producto: ").title().strip()
cantidad = int(input("Ingrese la cantidad: "))
precio_unitario = float(input("Precio del producto: "))

# Calculo del valor total del inventario
valor_total = cantidad * precio_unitario

# Mostrando los datos formateados
print("\n📦 Inventario Inicial")
print(f"Producto:{producto}",)
print(f"Cantidad:{cantidad}",)
print(f"Precio unitario: ${precio_unitario:.2f}", )
print(f"Valor total del inventario: ${valor_total:.2f}", )
print("🛒 Sistema de Control de Inventario")

# Solicitando información al usuario
producto = input("Ingrese el nombre del producto: ").title().strip()
cantidad = int(input("Ingrese la cantidad: "))
precio_unitario = float(input("Precio del producto: "))

# Mostrando los datos formateados
print("\n📦 Inventario Inicial")
print(f"Producto:{producto}",)
print(f"Cantidad:{cantidad}",)
print(f"Precio unitario: ${precio_unitario:.2f}", )
print(f"Valor total del inventario: ${valor_total:.2f}", )
print("🛒 Sistema de Control de Inventario")

# Cálculo del valor total del inventario
valor_total = cantidad * precio_unitario
# Out:
# 🛒 Bienvenidos
#
# 📦 Inventario Inicial
# Producto:Samung A55
# Cantidad:1
# Precio unitario: $349990.00
# Valor total del inventario: $349990.00
# 🛒 Sistema de Control de Inventario
#
# 📦 Inventario Inicial
# Producto:Fast Charger 20W
# Cantidad:1
# Precio unitario: $19990.00
# Valor total del inventario: $349990.00
# 🛒 Sistema de Control de Inventario
