# %% [markdown]
# # Tuplas - `tuple()`
#
# Estructuras de datos muy similares a las listas, pero con una **diferencia importante**: son **<u>inmutables</u>**, lo que significa que no puedes cambiar sus elementos una vez que la tupla ha sido creada. Las tuplas son muy útiles cuando necesitas asegurarte de que los datos no sean modificados, o cuando quieres un contenedor más eficiente en términos de memoria.
#
# ## Principales características
#
# * Se definen con paréntesis `()`.
#
# * Son **<u>inmutables</u>** (seguridad) (no puedes cambiar, agregar ni eliminar elementos).
#
# * Son **ordenadas**, lo que significa que puedes acceder a los elementos por su índice.
#
# * Pueden contener **cualquier tipo de dato** (números, cadenas, listas, etc.).
#
# * Debido a que son inmutables, las tuplas suelen ser más **rápidas** que las listas en operaciones de acceso.

# %% [markdown]
# # Creando una tupla - `tuple`

# %%
usuario = ("Matias", "Aguayo",25,False)

print(usuario)
print(type(usuario))
# Out:
# ('Matias', 'Aguayo', 25, False)
# <class 'tuple'>

# %% [markdown]
# # Accediendo a los elementos de una `tuple`

# %%
print(usuario[0])
print(usuario[1])
print(usuario[-1])
# Out:
# Matias
# Aguayo
# False

# %% [markdown]
# # Método `count()`
#
# Devuelve el número de veces que el valor x aparece en la tupla.

# %%
numeros = (1,2,34,34,34,11)

numeros.count(34)
# Out:
# 3

# %% [markdown]
# # Método `index`
#
# Devuelve el índice del primer elemento cuyo valor sea x. Si el valor no se encuentra, lanza un ValueError. Puedes especificar un rango de búsqueda usando los parámetros `start` y `end`.

# %%
print(numeros)

numeros.index(11)
# Out:
# (1, 2, 34, 34, 34, 11)
# 5

# %% [markdown]
# # Las `tuples` son **<u>inmutables</u>** !

# %%
print(usuario)
# Out:
# ('Matias', 'Aguayo', 25, False)

# %%
usuario[0] = "Santiago"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 usuario[0] = "Santiago"
#
# TypeError: 'tuple' object does not support item assignment

# %%
del usuario[-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 del usuario[-1]
#
# TypeError: 'tuple' object doesn't support item deletion
